# %%
import pandas as pd
import numpy as np

import requests
import re
from bs4 import BeautifulSoup
import difflib
from tqdm import tqdm
import os
import time

# %% [markdown]
# Preparation: Get paths to the pdfs

# %%
path_constant_part = "C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/"

pdf_path_dict = {
    1: '33_weisenberger.pdf',
    2: '714_brewster.pdf',
    3: '32_metzger.pdf',
    4: '40_buil.pdf', 
    5: '84_buil.pdf', 
    6: '61_manabe.pdf',
    7: '623_simpson.pdf',
    8: '184_tamaki.pdf',
    9: '624_simpson.pdf',
    10: '253_gamper.pdf',
    11: '23_manabe.pdf',
    12: '85_matsumura.pdf',
    13: '62_sano.pdf',
    14: '94_tessendorf.pdf',
    15: '25_akiyama.pdf',
    16: '20_manabe.pdf',
    17: '1_lissermann.pdf',
    18: '93_sahni.pdf',
    19: '7_bedri.pdf',
    20: '190_bleichner.pdf',
    21: '92_norton.pdf',
    22: '188_wang.pdf',
    23: '19_weigel.pdf',
    24: '63_ashbrook.pdf',
    25: '34_laput.pdf',
    26: '69_merrill.pdf',
    27: '43_nguyen.pdf',
    28: '17_ando.pdf',
    29: '206_dim.pdf',
    30: '22_kikuchi.pdf',
    31: '64_maag.pdf',
    32: '12_matthies.pdf',
    33: '111_wang.pdf',
    34: '117_ahn.pdf',
    35: '177_carioli.pdf',
    36: '91_favre_felix.pdf',
    37: '31_huang.pdf',
    38: '18_lee.pdf',
    39: '610_min.pdf',
    40: '65_nguyen.pdf',
    41: '60_taniguchi.pdf',
    42: '8_amesaka.pdf',
    43: '80_ferlini.pdf',
    44: '77_hoelzemann.pdf',
    45: '106_lee.pdf',
    46: '14_lee.pdf',
    47: '2_nasser.pdf',
    48: '78_odoemelem.pdf',
    49: '15_shirota.pdf',
    50: '620_vega_galvez.pdf',
    51: '27_yan.pdf',
    52: '223_cao.pdf',
    53: '234_chen.pdf',
    54: '212_chen.pdf',
    55: '149_kaveh.pdf',
    56: '16_prakash.pdf',
    57: '26_xu.pdf',
    58: '611_yang.pdf',
    59: '229_fan.pdf',
    60: '247_ferlini.pdf',
    61: '258_gashi.pdf',
    62: '217_hashem.pdf',
    63: '622_islam.pdf',
    64: '226_jin.pdf',
    65: '618_kakaraparthi.pdf',
    66: '213_khanna.pdf',
    67: '224_laporte.pdf',
    68: '626_ma.pdf',
    69: '259_nasser.pdf',
    70: '628_peng.pdf',
    71: '227_röddiger.pdf',
    72: '221_sun.pdf',
    73: '231_verma.pdf',
    74: '616_wu.pdf',
    75: '608_alkiek.pdf',
    76: '614_bi.pdf',
    77: '452_bi.pdf',
    78: '345_choi.pdf',
    79: '627_futami.pdf',
    80: '315_jin.pdf',
    81: '278_li.pdf',
    82: '512_song.pdf',
    83: '296_rateau.pdf',
    84: '307_srivastava.pdf',
    85: '309_wang.pdf',
    86: '306_wang.pdf',
    87: '388_yang.pdf',
    88: '284_alkiek.pdf',
    89: '344_chugh.pdf',
    90: '342_jin.pdf',
    91: '376_li.pdf',
    92: '308_panda.pdf',
    93: '443_paul.pdf',
    94: '277_stanke.pdf',
    95: '461_yi.pdf',
    96: '619_zhang.pdf',
    97: '292_zhang.pdf',
    98: '713_zhang.pdf',
    99: '516_zhu.pdf',
    100: '346_dong.pdf',
    101: '498_ge.pdf',
    102: '482_hu.pdf',
    103: '509_hu.pdf',
    104: '625_lepold.pdf',
    105: '449_ronco.pdf',
    106: '635_sato.pdf',
    107: '291_shojaeifard.pdf',
    108: '640_srivastava.pdf',
    109: '275_shimon.pdf',
    110: '654_srivastava.pdf',
    111: '506_sun.pdf',
    112: '639_suzuki.pdf',
    113: '286_wang.pdf',
    114: '532_wang.pdf',
    115: '676_wang.pdf',
    116: '675_xie.pdf',
    117: '354_yang.pdf',
    118: '527_yi.pdf',
}

pdf_path_dict_keys = list(pdf_path_dict.keys())

# %%
# Dictionary to track valid and invalid paths
path_status = {
    'valid': [],
    'invalid': []
}

# Loop through all entries in pdf_path_dict to check if files exist
print("Checking PDF file paths...")
for id_num, pdf_name in tqdm(pdf_path_dict.items()):
    full_path = os.path.join(path_constant_part, pdf_name)
    
    if os.path.isfile(full_path):
        path_status['valid'].append((id_num, pdf_name))
    else:
        path_status['invalid'].append((id_num, pdf_name))

# Print results
print(f"\nResults:")
print(f"- Valid paths: {len(path_status['valid'])}/{len(pdf_path_dict)}")
print(f"- Invalid paths: {len(path_status['invalid'])}/{len(pdf_path_dict)}")

# Print details of invalid paths if any exist
if path_status['invalid']:
    print("\nInvalid paths:")
    for id_num, pdf_name in path_status['invalid']:
        print(f"ID {id_num}: {path_constant_part}{pdf_name}")
# Out:
# Checking PDF file paths...
# 100%|██████████| 118/118 [00:00<00:00, 95934.85it/s]
# Results:
# - Valid paths: 0/118
# - Invalid paths: 118/118
#
# Invalid paths:
# ID 1: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/33_weisenberger.pdf
# ID 2: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/714_brewster.pdf
# ID 3: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/32_metzger.pdf
# ID 4: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/40_buil.pdf
# ID 5: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/84_buil.pdf
# ID 6: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/61_manabe.pdf
# ID 7: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/623_simpson.pdf
# ID 8: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/184_tamaki.pdf
# ID 9: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/624_simpson.pdf
# ID 10: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/253_gamper.pdf
# ID 11: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/23_manabe.pdf
# ID 12: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/85_matsumura.pdf
# ID 13: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/62_sano.pdf
# ID 14: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/94_tessendorf.pdf
# ID 15: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/25_akiyama.pdf
# ID 16: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/20_manabe.pdf
# ID 17: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/1_lissermann.pdf
# ID 18: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/93_sahni.pdf
# ID 19: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/7_bedri.pdf
# ID 20: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/190_bleichner.pdf
# ID 21: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/92_norton.pdf
# ID 22: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/188_wang.pdf
# ID 23: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/19_weigel.pdf
# ID 24: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/63_ashbrook.pdf
# ID 25: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/34_laput.pdf
# ID 26: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/69_merrill.pdf
# ID 27: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/43_nguyen.pdf
# ID 28: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/17_ando.pdf
# ID 29: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/206_dim.pdf
# ID 30: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/22_kikuchi.pdf
# ID 31: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/64_maag.pdf
# ID 32: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/12_matthies.pdf
# ID 33: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/111_wang.pdf
# ID 34: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/117_ahn.pdf
# ID 35: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/177_carioli.pdf
# ID 36: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/91_favre_felix.pdf
# ID 37: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/31_huang.pdf
# ID 38: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/18_lee.pdf
# ID 39: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/610_min.pdf
# ID 40: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/65_nguyen.pdf
# ID 41: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/60_taniguchi.pdf
# ID 42: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/8_amesaka.pdf
# ID 43: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/80_ferlini.pdf
# ID 44: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/77_hoelzemann.pdf
# ID 45: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/106_lee.pdf
# ID 46: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/14_lee.pdf
# ID 47: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/2_nasser.pdf
# ID 48: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/78_odoemelem.pdf
# ID 49: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/15_shirota.pdf
# ID 50: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/620_vega_galvez.pdf
# ID 51: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/27_yan.pdf
# ID 52: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/223_cao.pdf
# ID 53: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/234_chen.pdf
# ID 54: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/212_chen.pdf
# ID 55: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/149_kaveh.pdf
# ID 56: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/16_prakash.pdf
# ID 57: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/26_xu.pdf
# ID 58: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/611_yang.pdf
# ID 59: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/229_fan.pdf
# ID 60: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/247_ferlini.pdf
# ID 61: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/258_gashi.pdf
# ID 62: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/217_hashem.pdf
# ID 63: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/622_islam.pdf
# ID 64: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/226_jin.pdf
# ID 65: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/618_kakaraparthi.pdf
# ID 66: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/213_khanna.pdf
# ID 67: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/224_laporte.pdf
# ID 68: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/626_ma.pdf
# ID 69: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/259_nasser.pdf
# ID 70: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/628_peng.pdf
# ID 71: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/227_röddiger.pdf
# ID 72: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/221_sun.pdf
# ID 73: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/231_verma.pdf
# ID 74: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/616_wu.pdf
# ID 75: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/608_alkiek.pdf
# ID 76: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/614_bi.pdf
# ID 77: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/452_bi.pdf
# ID 78: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/345_choi.pdf
# ID 79: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/627_futami.pdf
# ID 80: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/315_jin.pdf
# ID 81: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/278_li.pdf
# ID 82: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/512_song.pdf
# ID 83: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/296_rateau.pdf
# ID 84: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/307_srivastava.pdf
# ID 85: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/309_wang.pdf
# ID 86: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/306_wang.pdf
# ID 87: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/388_yang.pdf
# ID 88: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/284_alkiek.pdf
# ID 89: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/344_chugh.pdf
# ID 90: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/342_jin.pdf
# ID 91: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/376_li.pdf
# ID 92: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/308_panda.pdf
# ID 93: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/443_paul.pdf
# ID 94: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/277_stanke.pdf
# ID 95: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/461_yi.pdf
# ID 96: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/619_zhang.pdf
# ID 97: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/292_zhang.pdf
# ID 98: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/713_zhang.pdf
# ID 99: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/516_zhu.pdf
# ID 100: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/346_dong.pdf
# ID 101: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/498_ge.pdf
# ID 102: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/482_hu.pdf
# ID 103: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/509_hu.pdf
# ID 104: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/625_lepold.pdf
# ID 105: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/449_ronco.pdf
# ID 106: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/635_sato.pdf
# ID 107: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/291_shojaeifard.pdf
# ID 108: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/640_srivastava.pdf
# ID 109: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/275_shimon.pdf
# ID 110: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/654_srivastava.pdf
# ID 111: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/506_sun.pdf
# ID 112: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/639_suzuki.pdf
# ID 113: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/286_wang.pdf
# ID 114: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/532_wang.pdf
# ID 115: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/676_wang.pdf
# ID 116: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/675_xie.pdf
# ID 117: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/354_yang.pdf
# ID 118: C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/527_yi.pdf

# %% [markdown]
# Get the Citation Matrix of out of the PDFs

# %%
# DF with ID and bibtex
df_id_bibtex = pd.read_excel('interconnections_datasets/bibtex_mapping_of_ids.xlsx')

# %%
# Function to extract references from a paper using GROBID and convert to BibTeX
def extract_references_to_bibtex(pdf_path):
    """Extract references from PDF using GROBID and convert to BibTeX format"""
    references = []
    
    try:
        # Read PDF content
        with open(pdf_path, "rb") as pdf_file:
            pdf_content = pdf_file.read()
        
        # Request GROBID to process references
        files = {"input": ("document.pdf", pdf_content, "application/pdf")}
        response = requests.post(
            "http://localhost:8070/api/processReferences", 
            files=files, 
            timeout=300
        )
        
        if response.status_code != 200:
            print(f"Error from GROBID API: {response.status_code}")
            return []
            
        # Parse XML response
        soup = BeautifulSoup(response.text, 'xml')
        
        for i, bibl in enumerate(soup.find_all('biblStruct')):
            # Extract key citation components
            ref_id = bibl.get('xml:id', f'ref_{i}')
            
            # Authors
            authors = []
            for author_tag in bibl.find_all('author'):
                person = author_tag.find('persName')
                if person:
                    surname = person.find('surname')
                    forename = person.find('forename')
                    
                    if surname:
                        author_name = surname.text
                        if forename:
                            author_name = f"{author_name}, {forename.text}"
                        authors.append(author_name)
            
            # Title
            title = ""
            title_tag = bibl.find('title', {'level': 'a'})
            if title_tag:
                title = title_tag.text.strip()
            
            # Year
            year = ""
            date_tag = bibl.find('date', {'type': 'published'})
            if date_tag and date_tag.get('when'):
                year = date_tag.get('when').split('-')[0]  # Extract year from date
            
            # Journal/Conference
            journal = ""
            journal_tag = bibl.find('title', {'level': 'j'})
            if journal_tag:
                journal = journal_tag.text.strip()
            else:
                book_tag = bibl.find('title', {'level': 'm'})
                if book_tag:
                    journal = book_tag.text.strip()
            
            # Volume, Issue, Pages
            volume = ""
            vol_tag = bibl.find('biblScope', {'unit': 'volume'})
            if vol_tag:
                volume = vol_tag.text.strip()
            
            issue = ""
            issue_tag = bibl.find('biblScope', {'unit': 'issue'})
            if issue_tag:
                issue = issue_tag.text.strip()
            
            pages = ""
            pages_from_tag = bibl.find('biblScope', {'unit': 'page', 'from': True})
            pages_to_tag = bibl.find('biblScope', {'unit': 'page', 'to': True})
            if pages_from_tag and pages_to_tag:
                pages = f"{pages_from_tag.get('from')}--{pages_to_tag.get('to')}"
            elif pages_from_tag:
                pages = pages_from_tag.get('from')
            
            # DOI
            doi = ""
            doi_tag = bibl.find('idno', {'type': 'DOI'})
            if doi_tag:
                doi = doi_tag.text.strip()
            
            # Create BibTeX entry
            bibtex_id = f"grobid_{ref_id.replace('b', '')}"
            bibtex_str = f"@article{{{bibtex_id},\n"
            
            if authors:
                bibtex_str += f"  author = {{{' and '.join(authors)}}},\n"
            if title:
                bibtex_str += f"  title = {{{title}}},\n"
            if journal:
                bibtex_str += f"  journal = {{{journal}}},\n"
            if year:
                bibtex_str += f"  year = {{{year}}},\n"
            if volume:
                bibtex_str += f"  volume = {{{volume}}},\n"
            if issue:
                bibtex_str += f"  number = {{{issue}}},\n"
            if pages:
                bibtex_str += f"  pages = {{{pages}}},\n"
            if doi:
                bibtex_str += f"  doi = {{{doi}}},\n"
                
            bibtex_str += "}"
            
            # Create structured citation data
            citation = {
                'bibtex': bibtex_str,
                'authors': authors,
                'title': title,
                'year': year,
                'journal': journal,
                'doi': doi,
                'raw_xml': str(bibl),
                'author_last_names': [a.split(',')[0].lower().strip() if ',' in a else a.split()[-1].lower().strip() 
                                      for a in authors]
            }
            
            references.append(citation)
            
    except Exception as e:
        print(f"Error extracting references: {str(e)}")
    
    return references

# %%
# Function to normalize BibTeX entries for comparison
def normalize_bibtex_for_comparison(bibtex_str):
    """Extract key information from BibTeX for comparison"""
    result = {
        'authors': [],
        'title': '',
        'year': '',
        'journal': '',
        'doi': '',
        'author_last_names': []
    }
    
    # Extract authors
    author_match = re.search(r'author\s*=\s*\{(.*?)\}', bibtex_str, re.DOTALL)
    if author_match:
        authors_str = author_match.group(1)
        authors = [a.strip() for a in authors_str.split(' and ')]
        result['authors'] = authors
        # Extract last names
        result['author_last_names'] = [a.split(',')[0].lower().strip() if ',' in a 
                                      else a.split()[-1].lower().strip() 
                                      for a in authors]
    
    # Extract title
    title_match = re.search(r'title\s*=\s*\{(.*?)\}', bibtex_str, re.DOTALL)
    if title_match:
        result['title'] = re.sub(r'[\{\}]', '', title_match.group(1).lower())
    
    # Extract year
    year_match = re.search(r'year\s*=\s*\{?(\d{4})\}?', bibtex_str)
    if year_match:
        result['year'] = year_match.group(1)
    
    # Extract journal or booktitle
    journal_match = re.search(r'journal\s*=\s*\{(.*?)\}', bibtex_str, re.DOTALL)
    if not journal_match:
        journal_match = re.search(r'booktitle\s*=\s*\{(.*?)\}', bibtex_str, re.DOTALL)
    if journal_match:
        result['journal'] = journal_match.group(1).lower()
    
    # Extract DOI
    doi_match = re.search(r'doi\s*=\s*\{(.*?)\}', bibtex_str, re.DOTALL)
    if doi_match:
        result['doi'] = doi_match.group(1).lower()
    
    return result

# %%
# Function to match citation with corpus papers
def match_citation_to_corpus(citation_data, corpus_entries, citing_paper_id, threshold=0.5):
    """Match a citation to papers in the corpus"""
    matches = []
    
    # Extract normalized data from citation
    citation_title = citation_data.get('title', '').lower()
    citation_title = re.sub(r'[^\w\s]', '', citation_title)
    citation_year = citation_data.get('year', '')
    citation_authors = citation_data.get('author_last_names', [])
    citation_doi = citation_data.get('doi', '').lower()
    
    for paper_id, paper_data in corpus_entries.items():
        # Skip self-citations (ADDED)
        if paper_id == citing_paper_id:
            continue
            
        score = 0
        max_score = 0
        match_details = {}
        
        # Extract normalized data from corpus entry
        paper_title = paper_data.get('title', '').lower()
        paper_title = re.sub(r'[^\w\s]', '', paper_title)
        paper_year = paper_data.get('year', '')
        paper_authors = paper_data.get('author_last_names', [])
        paper_doi = paper_data.get('doi', '').lower()
        
        # Match by DOI (highest confidence)
        if citation_doi and paper_doi and citation_doi == paper_doi:
            return [{'paper_id': paper_id, 'score': 1.0, 'match_type': 'doi'}]
        
        # Match by authors (up to 2 points)
        if citation_authors and paper_authors:
            max_score += 2
            matching_authors = set(citation_authors) & set(paper_authors)
            if matching_authors:
                author_score = min(2, len(matching_authors))
                score += author_score
                match_details['matching_authors'] = list(matching_authors)
        
        # Match by year (1 point)
        if citation_year and paper_year:
            max_score += 1
            if citation_year == paper_year:
                score += 1
                match_details['year_match'] = True
        
        # Match by title (5 points max)
        if citation_title and paper_title:
            max_score += 5
            
            # Calculate title similarity
            title_similarity = difflib.SequenceMatcher(None, citation_title, paper_title).ratio()
            
            # Check for title containment (special case)
            if (len(citation_title) > 10 and len(paper_title) > 10):
                if citation_title in paper_title or paper_title in citation_title:
                    title_similarity = max(title_similarity, 0.8)
            
            title_score = title_similarity * 5
            score += title_score
            match_details['title_similarity'] = title_similarity
        
        # Calculate final score
        if max_score > 0:
            final_score = score / max_score
            if final_score >= threshold:
                matches.append({
                    'paper_id': paper_id,
                    'score': final_score,
                    'details': match_details
                })
    
    # Sort matches by score
    matches.sort(key=lambda x: x['score'], reverse=True)
    return matches

# %%
# Function to build citation network with Excel-based confirmation
def build_citation_network_with_excel(df_id_bibtex, pdf_path_dict, path_constant_part):
    """Build a citation network from papers and their references with Excel-based confirmation"""
    print("Preparing citation network analysis...")
    
    # Step 1: Create normalized corpus entries from BibTeX data
    print("Normalizing corpus BibTeX entries...")
    corpus_entries = {}
    
    for _, row in df_id_bibtex.iterrows():
        paper_id = row['ID']
        bibtex_str = row['Bibtex'] if isinstance(row['Bibtex'], str) else ""
        
        if bibtex_str:
            normalized_data = normalize_bibtex_for_comparison(bibtex_str)
            corpus_entries[paper_id] = normalized_data
    
    print(f"Normalized {len(corpus_entries)} papers in corpus")
    
    # Step 2: Initialize citation matrix
    paper_ids = list(corpus_entries.keys())
    citation_matrix = pd.DataFrame(0, index=paper_ids, columns=paper_ids)
    
    # Step 3: Extract all references first 
    print("First extracting all references from papers...")
    all_paper_references = {}
    
    # Create output directory for citations
    os.makedirs("extracted_citations", exist_ok=True)
    
    for paper_id in tqdm(corpus_entries.keys()):
        
        time.sleep(1)  # To avoid overwhelming the server
        
        if paper_id in pdf_path_dict:
            pdf_path = f"{path_constant_part}{pdf_path_dict[paper_id]}"
            
            # Extract references
            print(f"\nExtracting references from paper {paper_id}...")
            references = extract_references_to_bibtex(pdf_path)
            print(f"Found {len(references)} references in paper {paper_id}")
            
            # Save references to file
            with open(f"extracted_citations/paper_{paper_id}_citations.bib", "w", encoding="utf-8") as f:
                for ref in references:
                    f.write(ref['bibtex'] + "\n\n")
            
            all_paper_references[paper_id] = references
    
    # Step 4: Match references to corpus and collect uncertain matches
    print("\nMatching references to corpus papers...")
    citation_details = {}
    uncertain_matches = []  # Store uncertain matches for Excel confirmation
    high_confidence_matches = []  # Store high confidence matches
    
    for citing_id, references in all_paper_references.items():
        citation_details[citing_id] = []
        
        for ref_idx, ref in enumerate(references):
            matches = match_citation_to_corpus(ref, corpus_entries, citing_id)
            
            if matches:
                best_match = matches[0]
                cited_id = best_match['paper_id']
                match_score = best_match['score']
                
                # High-confidence match (add directly)
                if match_score >= 0.7:
                    citation_matrix.loc[citing_id, cited_id] = 1
                    high_confidence_matches.append({
                        'citing_id': citing_id,
                        'cited_id': cited_id,
                        'score': match_score,
                        'citation_title': ref.get('title', ''),
                        'citation_authors': ', '.join(ref.get('authors', [])),
                        'citation_year': ref.get('year', ''),
                        'confidence': 'high',
                        'matching_authors': ', '.join(best_match.get('details', {}).get('matching_authors', [])),
                        'title_similarity': best_match.get('details', {}).get('title_similarity', 0),
                        'year_match': 'Yes' if best_match.get('details', {}).get('year_match', False) else 'No',
                        'confirmed': 'Yes'  # Auto-confirmed due to high confidence
                    })
                    print(f"✓ Paper {citing_id} cites paper {cited_id} (score: {match_score:.2f})")
                
                # Uncertain match (store for Excel confirmation)
                elif match_score >= 0.5:
                    citing_filename = pdf_path_dict.get(citing_id, f"Unknown-{citing_id}")
                    cited_filename = pdf_path_dict.get(cited_id, f"Unknown-{cited_id}")
                    
                    uncertain_matches.append({
                        'citing_id': citing_id,
                        'citing_filename': citing_filename,
                        'cited_id': cited_id,
                        'cited_filename': cited_filename,
                        'score': match_score,
                        'citation_title': ref.get('title', ''),
                        'citation_authors': ', '.join(ref.get('authors', [])),
                        'citation_year': ref.get('year', ''),
                        'confidence': 'medium',
                        'matching_authors': ', '.join(best_match.get('details', {}).get('matching_authors', [])),
                        'title_similarity': best_match.get('details', {}).get('title_similarity', 0),
                        'year_match': 'Yes' if best_match.get('details', {}).get('year_match', False) else 'No',
                        'confirmed': ''  # To be filled in Excel
                    })
                    print(f"? Uncertain match: Paper {citing_id} possibly cites paper {cited_id} (score: {match_score:.2f})")
    
    # Step 5: Export uncertain matches to Excel
    if uncertain_matches:
        print(f"\nExporting {len(uncertain_matches)} uncertain matches to Excel...")
        uncertain_df = pd.DataFrame(uncertain_matches)
        
        # Add instructions in first row
        instructions = pd.DataFrame([{
            'citing_id': 'INSTRUCTIONS',
            'citing_filename': 'Fill in the "confirmed" column with: Yes, No, or leave blank to skip',
            'cited_id': '',
            'cited_filename': '',
            'score': '',
            'citation_title': '',
            'citation_authors': '', 
            'citation_year': '',
            'confidence': '',
            'matching_authors': '',
            'title_similarity': '',
            'year_match': '',
            'confirmed': ''
        }])
        
        # Combine instructions with data
        export_df = pd.concat([instructions, uncertain_df], ignore_index=True)
        
        # Export to Excel
        excel_path = 'citation_confirmation.xlsx'
        export_df.to_excel(excel_path, index=False)
        print(f"Exported uncertain matches to {excel_path}")
        print("Please fill in the 'confirmed' column with 'Yes' or 'No' and save the file.")
        print("Then run the import_citation_confirmations() function to update the citation matrix.")
    
    # Also export high confidence matches for reference
    if high_confidence_matches:
        high_conf_df = pd.DataFrame(high_confidence_matches)
        high_conf_df.to_excel('high_confidence_citations.xlsx', index=False)
    
    return citation_matrix, citation_details, uncertain_matches

# %%
def import_citation_confirmations(citation_matrix):
    """Import citation confirmations from Excel and update the citation matrix"""
    confirmation_file = 'citation_confirmation.xlsx'
    
    if not os.path.exists(confirmation_file):
        print(f"Error: Confirmation file {confirmation_file} not found.")
        return citation_matrix
    
    # Load confirmations, skipping the instruction row
    confirmations = pd.read_excel(confirmation_file, header=0, skiprows=[1])
        
    # Count statistics
    confirmed_count = 0
    rejected_count = 0
    skipped_count = 0
    
    # Process each confirmation
    for _, row in confirmations.iterrows():
        citing_id = row['citing_id']
        cited_id = row['cited_id']
        confirmation = str(row['confirmed']).strip().lower()
        
        if confirmation == 'yes':
            citation_matrix.loc[citing_id, cited_id] = 1
            confirmed_count += 1
        elif confirmation == 'no':
            # Ensure it's set to 0 (though it should already be)
            citation_matrix.loc[citing_id, cited_id] = 0
            rejected_count += 1
        else:
            skipped_count += 1
    
    # Print summary
    print(f"\nCitation Confirmation Summary:")
    print(f"- Confirmed: {confirmed_count}")
    print(f"- Rejected: {rejected_count}")
    print(f"- Skipped: {skipped_count}")
    
    # Save updated matrix
    citation_matrix.to_csv('interconnections_datasets/citation_matrix.csv')
    print("Updated citation matrix saved to 'interconnections_datasets/citation_matrix.csv'")
    
    return citation_matrix

# %%
# Execute the modified pipeline
citation_matrix, citation_details, uncertain_matches = build_citation_network_with_excel(
    df_id_bibtex, 
    pdf_path_dict, 
    path_constant_part
)

# Save initial citation matrix (with only high-confidence matches)
citation_matrix.to_csv('interconnections_datasets/citation_matrix_initial.csv')

# Display instructions for the user
print("\n" + "="*80)
print("NEXT STEPS:")
print("1. Open the file 'citation_confirmation.xlsx'")
print("2. For each row, review the potential citation")
print("3. In the 'confirmed' column, enter:")
print("   - 'Yes' if it's a valid citation")
print("   - 'No' if it's not a valid citation")
print("   - Leave blank to skip")
print("4. Save the file and run the code below to update the citation matrix:")
print("   citation_matrix = import_citation_confirmations(citation_matrix)")
print("="*80)
# Out:
# Preparing citation network analysis...
# Normalizing corpus BibTeX entries...
# Normalized 118 papers in corpus
# First extracting all references from papers...
#   1%|          | 1/118 [00:01<01:57,  1.00s/it]
# Extracting references from paper 1...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/33_weisenberger.pdf'
# Found 0 references in paper 1
#   2%|▏         | 2/118 [00:02<01:56,  1.00s/it]
# Extracting references from paper 2...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/714_brewster.pdf'
# Found 0 references in paper 2
#   3%|▎         | 3/118 [00:03<01:55,  1.00s/it]
# Extracting references from paper 3...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/32_metzger.pdf'
# Found 0 references in paper 3
#   3%|▎         | 4/118 [00:04<01:54,  1.00s/it]
# Extracting references from paper 4...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/40_buil.pdf'
# Found 0 references in paper 4
#   4%|▍         | 5/118 [00:05<01:53,  1.00s/it]
# Extracting references from paper 5...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/84_buil.pdf'
# Found 0 references in paper 5
#   5%|▌         | 6/118 [00:06<01:52,  1.00s/it]
# Extracting references from paper 6...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/61_manabe.pdf'
# Found 0 references in paper 6
#   6%|▌         | 7/118 [00:07<01:51,  1.00s/it]
# Extracting references from paper 7...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/623_simpson.pdf'
# Found 0 references in paper 7
#   7%|▋         | 8/118 [00:08<01:50,  1.00s/it]
# Extracting references from paper 8...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/184_tamaki.pdf'
# Found 0 references in paper 8
#   8%|▊         | 9/118 [00:09<01:49,  1.00s/it]
# Extracting references from paper 9...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/624_simpson.pdf'
# Found 0 references in paper 9
#   8%|▊         | 10/118 [00:10<01:48,  1.00s/it]
# Extracting references from paper 10...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/253_gamper.pdf'
# Found 0 references in paper 10
#   9%|▉         | 11/118 [00:11<01:47,  1.00s/it]
# Extracting references from paper 11...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/23_manabe.pdf'
# Found 0 references in paper 11
#  10%|█         | 12/118 [00:12<01:46,  1.00s/it]
# Extracting references from paper 12...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/85_matsumura.pdf'
# Found 0 references in paper 12
#  11%|█         | 13/118 [00:13<01:45,  1.00s/it]
# Extracting references from paper 13...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/62_sano.pdf'
# Found 0 references in paper 13
#  12%|█▏        | 14/118 [00:14<01:44,  1.00s/it]
# Extracting references from paper 14...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/94_tessendorf.pdf'
# Found 0 references in paper 14
#  13%|█▎        | 15/118 [00:15<01:43,  1.00s/it]
# Extracting references from paper 15...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/25_akiyama.pdf'
# Found 0 references in paper 15
#  14%|█▎        | 16/118 [00:16<01:42,  1.00s/it]
# Extracting references from paper 16...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/20_manabe.pdf'
# Found 0 references in paper 16
#  14%|█▍        | 17/118 [00:17<01:41,  1.00s/it]
# Extracting references from paper 17...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/1_lissermann.pdf'
# Found 0 references in paper 17
#  15%|█▌        | 18/118 [00:18<01:40,  1.00s/it]
# Extracting references from paper 18...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/93_sahni.pdf'
# Found 0 references in paper 18
#  16%|█▌        | 19/118 [00:19<01:39,  1.00s/it]
# Extracting references from paper 19...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/7_bedri.pdf'
# Found 0 references in paper 19
#  17%|█▋        | 20/118 [00:20<01:38,  1.00s/it]
# Extracting references from paper 20...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/190_bleichner.pdf'
# Found 0 references in paper 20
#  18%|█▊        | 21/118 [00:21<01:37,  1.00s/it]
# Extracting references from paper 21...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/92_norton.pdf'
# Found 0 references in paper 21
#  19%|█▊        | 22/118 [00:22<01:36,  1.00s/it]
# Extracting references from paper 22...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/188_wang.pdf'
# Found 0 references in paper 22
#  19%|█▉        | 23/118 [00:23<01:35,  1.00s/it]
# Extracting references from paper 23...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/19_weigel.pdf'
# Found 0 references in paper 23
#  20%|██        | 24/118 [00:24<01:34,  1.00s/it]
# Extracting references from paper 24...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/63_ashbrook.pdf'
# Found 0 references in paper 24
#  21%|██        | 25/118 [00:25<01:33,  1.00s/it]
# Extracting references from paper 25...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/34_laput.pdf'
# Found 0 references in paper 25
#  22%|██▏       | 26/118 [00:26<01:32,  1.00s/it]
# Extracting references from paper 26...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/69_merrill.pdf'
# Found 0 references in paper 26
#  23%|██▎       | 27/118 [00:27<01:31,  1.00s/it]
# Extracting references from paper 27...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/43_nguyen.pdf'
# Found 0 references in paper 27
#  24%|██▎       | 28/118 [00:28<01:30,  1.00s/it]
# Extracting references from paper 28...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/17_ando.pdf'
# Found 0 references in paper 28
#  25%|██▍       | 29/118 [00:29<01:29,  1.00s/it]
# Extracting references from paper 29...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/206_dim.pdf'
# Found 0 references in paper 29
#  25%|██▌       | 30/118 [00:30<01:28,  1.00s/it]
# Extracting references from paper 30...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/22_kikuchi.pdf'
# Found 0 references in paper 30
#  26%|██▋       | 31/118 [00:31<01:27,  1.00s/it]
# Extracting references from paper 31...
# Error extracting references: [Errno 2] No such file or directory: 'C:/Users/Jonas Hummel/Documents/Studium - PhD Informatik/Survey Paper Interaction/Study PDFs/64_maag.pdf'
# Found 0 references in paper 31
#  26%|██▋       | 31/118 [00:32<01:29,  1.03s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Execute the modified pipeline
# ----> 2 citation_matrix, citation_details, uncertain_matches = build_citation_network_with_excel(
#       3     df_id_bibtex,
#       4     pdf_path_dict,
#       5     path_constant_part
#       6 )
#       8 # Save initial citation matrix (with only high-confidence matches)
#       9 citation_matrix.to_csv('interconnections_datasets/citation_matrix_initial.csv')
#
# Cell In[8], line 33, in build_citation_network_with_excel(df_id_bibtex, pdf_path_dict, path_constant_part)
#      29 os.makedirs("extracted_citations", exist_ok=True)
#      31 for paper_id in tqdm(corpus_entries.keys()):
# ---> 33     time.sleep(1)  # To avoid overwhelming the server
#      35     if paper_id in pdf_path_dict:
#      36         pdf_path = f"{path_constant_part}{pdf_path_dict[paper_id]}"
#
# KeyboardInterrupt:

# %%
# Note: There is an error for the Paper 15 since the PDF seems not well-readable. It cites none of the other studies anyways.

# %%
# To run after manual confirmation:
citation_matrix = import_citation_confirmations(citation_matrix)

# Print summary statistics
num_citations = citation_matrix.sum().sum()
num_papers_with_citations = (citation_matrix.sum(axis=1) > 0).sum()
num_papers_cited = (citation_matrix.sum(axis=0) > 0).sum()

print(f"\nUpdated Citation Network Summary:")
print(f"Total citations between corpus papers: {num_citations}")
print(f"Papers that cite others in the corpus: {num_papers_with_citations}")
print(f"Papers that are cited by others: {num_papers_cited}")
# Out:
# Citation Confirmation Summary:
# - Confirmed: 65
# - Rejected: 183
# - Skipped: 0
# Updated citation matrix saved to 'interconnections_datasets/citation_matrix.csv'
#
# Updated Citation Network Summary:
# Total citations between corpus papers: 465
# Papers that cite others in the corpus: 96
# Papers that are cited by others: 90

# %%
# Identify cases where a paper cites another with a higher ID (could be due to same year; want to avoid abvious logical errors)
forward_citations = []

# Iterate through the citation matrix
for citing_id in citation_matrix.index:
    for cited_id in citation_matrix.columns:
        # Check if this is a forward citation (earlier paper citing later paper)
        if citing_id < cited_id and citation_matrix.loc[citing_id, cited_id] == 1:
            forward_citations.append((citing_id, cited_id))

# Print the results
print(f"Found {len(forward_citations)} forward citations (earlier papers citing later papers):")
if forward_citations:
    for citing_id, cited_id in forward_citations:
        print(f"Paper {citing_id} cites paper {cited_id}")
else:
    print("No forward citations found.")
# Out:
# Found 13 forward citations (earlier papers citing later papers):
# Paper 4 cites paper 5
# Paper 46 cites paper 68
# Paper 54 cites paper 68
# Paper 59 cites paper 60
# Paper 61 cites paper 63
# Paper 61 cites paper 64
# Paper 61 cites paper 68
# Paper 76 cites paper 77
# Paper 93 cites paper 104
# Paper 106 cites paper 109
# Paper 106 cites paper 111
# Paper 108 cites paper 110
# Paper 112 cites paper 117

# %%
# List of specific forward citations to remove
citations_to_correct = [
    # List the 7 specific pairs you want to remove as (citing_id, cited_id)
    # For example:
    (4, 5),
    (46, 68),
    (54, 68),
    (59, 60),
    (61, 64),
    (61, 68),
    (93, 104)
    # Add all 7 pairs here
]

# Make a copy of the original citation matrix to avoid modifying the original
corrected_matrix = citation_matrix.copy()

# Modify the specified citations
for citing_id, cited_id in citations_to_correct:
    print(f"Removing citation: Paper {citing_id} → Paper {cited_id}")
    corrected_matrix.loc[citing_id, cited_id] = 0

# Save the corrected citation matrix
corrected_matrix.to_csv('interconnections_datasets/citation_matrix.csv')

# Verify the corrections
forward_citations_after = []
for citing_id in corrected_matrix.index:
    for cited_id in corrected_matrix.columns:
        if citing_id < cited_id and corrected_matrix.loc[citing_id, cited_id] == 1:
            forward_citations_after.append((citing_id, cited_id))

print(f"\nAfter correction: {len(forward_citations_after)} forward citations remain.")
if forward_citations_after:
    print("Remaining forward citations:")
    for citing_id, cited_id in forward_citations_after:
        print(f"Paper {citing_id} still cites paper {cited_id}")
else:
    print("All specified forward citations have been removed.")
# Out:
# Removing citation: Paper 4 → Paper 5
# Removing citation: Paper 46 → Paper 68
# Removing citation: Paper 54 → Paper 68
# Removing citation: Paper 59 → Paper 60
# Removing citation: Paper 61 → Paper 64
# Removing citation: Paper 61 → Paper 68
# Removing citation: Paper 93 → Paper 104
#
# After correction: 6 forward citations remain.
# Remaining forward citations:
# Paper 61 still cites paper 63
# Paper 76 still cites paper 77
# Paper 106 still cites paper 109
# Paper 106 still cites paper 111
# Paper 108 still cites paper 110
# Paper 112 still cites paper 117
